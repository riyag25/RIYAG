# %% [markdown]
# ## Q&A Activity Question Week -09
# Do the following on the dataset
# 1. Explain the dataset
# 2. Check the summary statistics and discuss the max, min, avg, median,
# and percentiles.
# 3. The manager wants to find out whether the same amount was spent
# for the three advertisements (TV , Radio and Newspaper). Comment
# on your findings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('Advertising.csv')

# %% [markdown]
# ## Explain the data

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.drop('Unnamed: 0',axis =1,inplace =True)

# %%
sns.lineplot(data =df)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data =df, x = 'TV', y ='Sales')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(data =df, x = 'Radio', y ='Sales')
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(data =df, x = 'Newspaper', y ='Sales')
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# Data shows 200 records for the amount spent for advertisement on  TV,radio and Newspaper and the corresponding variations in  sales amount. Data appears to be not in actual scales.The features need to be multiplied by scaling factor to observe the proper results.

# %% [markdown]
# ## Check the summary statistics and discuss the max, min, avg, median, and percentiles.

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df[['TV','Sales','Radio','Newspaper']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## The manager wants to find out whether the same amount was spent for the three advertisements (TV , Radio and Newspaper). Comment on your findings

# %%
df[['TV','Radio','Newspaper']].hist()
plt.show()

# %% [markdown]
# THe 3 features are independednt. We will use ANOVA test.

# %%
from scipy.stats import f_oneway

# %%
# H0:Same amount was spent for 3 advertisement.
# H1:  Different amount was spent for 3 advertisement.
# alpha : .05

# %%
f_oneway(df['TV'],df['Radio'], df['Newspaper'])
# Out:
# F_onewayResult(statistic=358.8514595342597, pvalue=4.552931539744962e-103)

# %% [markdown]
# ***
# Since pvalue is less than alpha, we will reject the null hypothesis. We can conclude that different amount was spent for 3 advertisement.
# ***
